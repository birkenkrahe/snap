# %% [markdown]
# <a href="https://colab.research.google.com/github/birkenkrahe/snap/blob/piHome/SnapToPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My first Python program
#
# This program is a Python transcription of the following Snap! code block:

# %% [markdown]
# ![snap_name_age.png](data:image/png;base64,...)

# %%
print('hello world')
# Out:
# hello world

# %%
print("What's your name?")
# Out:
# What's your name?

# %%
name = input()
# Out:
# Marcus

# %%
name
# Out:
# 'Marcus'

# %%
print('Your name has', len(name), 'characters')
# Out:
# Your name has 6 characters

# %%
age = input("What's your age? ")
# Out:
# What's your age?29

# %%
print(f"You're going to be {str(int(age)+1)} years old.")
# Out:
# You're going to be 30 years old.

# %% [markdown]
# To save the code blocks as one Python program `hello.py`, select `File` > `Download` > `Download .py` in the top menu.
